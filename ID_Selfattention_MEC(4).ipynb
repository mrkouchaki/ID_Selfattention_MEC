# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, RepeatVector, TimeDistributed, Layer
from tensorflow.keras.layers import MultiHeadAttention
from tensorflow.keras.layers import Masking
import pandas as pd
import glob
import matplotlib.pyplot as plt
import os
import struct
import glob
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, classification_report, accuracy_score
# MEC related functions
def mec_kocaoglu_np(p, q):
    p = p.copy().astype(np.float64) / p.sum()
    q = q.copy().astype(np.float64) / q.sum()
    J = np.zeros((len(q), len(p)), dtype=np.float64)
    M = np.stack((p, q), 0)
    r = M.max(axis=1).min()
    while r > 0:
        a_i = M.argmax(axis=1)
        M[0, a_i[0]] -= r
        M[1, a_i[1]] -= r
        J[a_i[0], a_i[1]] = r
        r = M.max(axis=1).min()
    return J

def apply_mec_to_data(data):
    data_distribution = np.histogram(data, bins='auto')[0].astype(np.float64)
    data_distribution /= data_distribution.sum()
    mec_transformed = mec_kocaoglu_np(data_distribution, data_distribution)
    return mec_transformed.sum(0)

# Custom loss function
# def custom_loss(y_true, y_pred):
#     mse = tf.reduce_mean(tf.square(y_true - y_pred))
#     entropy_reg = -tf.reduce_mean(y_pred * tf.math.log(y_pred + 1e-9))
#     lambda_entropy = 0.01
#     return mse + lambda_entropy * entropy_reg
def custom_loss(y_true, y_pred):
    mse = tf.reduce_mean(tf.square(y_true - y_pred))
    y_pred_clipped = tf.clip_by_value(y_pred, 1e-9, 1.0)  # Clip values to avoid log(0)
    entropy_reg = -tf.reduce_mean(y_pred_clipped * tf.math.log(y_pred_clipped))
    lambda_entropy = 0.01
    return mse + lambda_entropy * entropy_reg

# Data Generator
class CSVDataGenerator:
    def __init__(self, file_pattern, batch_size, sequence_length, max_samples=None, for_training=True):     
        self.file_pattern = file_pattern
        self.file_list = sorted(glob.glob(self.file_pattern))
        self.batch_size = batch_size
        self.sequence_length = sequence_length
        self.max_samples = max_samples
        self.for_training = for_training
        self.current_file_idx = 0
        self.dataframe_iterator = None
        self.labels_iterator = None
        self.samples_buffer = []
        self.labels_buffer = []
        self.total_samples_processed = 0

    def _load_next_file(self):
        if self.current_file_idx >= len(self.file_list):
            print("No more files to process.")
            raise StopIteration

        current_file = self.file_list[self.current_file_idx]
        df = pd.read_csv(current_file)
        # Filter out rows where 'IQ Data' is '0j'
        df['IQ Data'] = df['IQ Data'].apply(lambda x: complex(x.replace('i', 'j')))
        df = df[df['IQ Data'] != 0j]
        # Check if DataFrame is empty or 'IQ Data' column is missing
        if df.empty or 'IQ Data' not in df.columns:
            raise ValueError(f"File {current_file} is empty or missing 'IQ Data' column after filtering 0j.")
        # If not for training, extract the labels
        if not self.for_training and 'label' in df.columns:
            self.labels_iterator = iter(df['label'].map(lambda x: 1 if x == 'jammer' else 0).values)
        else:
            self.labels_iterator = None
        print(f"Processing file: {current_file}")
        self.dataframe_iterator = iter(df['IQ Data'].values)
        self.current_file_idx += 1

    # Reset function to be used when switching from training to prediction
    def reset_for_prediction(self):
        self.current_file_idx = 0
        self.samples_buffer = []
        self.labels_buffer = []
        self.total_samples_processed = 0
        self.dataframe_iterator = None
        self._load_next_file()  # Start from the first file again

    def __iter__(self):
        self.current_file_idx = 0
        self.samples_buffer = []
        self.labels_buffer = []
        self.total_samples_processed = 0
        self._load_next_file()
        return self
    
    def process_data(self, samples):
        real_parts = np.real(samples)
        imag_parts = np.imag(samples)
        #print(f"real_parts in process_data: {real_parts}")
        #print(f"imag_parts in process_data: {imag_parts}")

        transformed_real = apply_mec_to_data(real_parts)
        transformed_imag = apply_mec_to_data(imag_parts)
        #print(f"Transformed transformed_real before padding: {transformed_real}")
        #print(f"Transformed transformed_imag before padding: {transformed_imag}")
        
        # Determine the max_length as the closest multiple of sequence_length
        max_length = max(len(transformed_real), len(transformed_imag))
        if max_length % self.sequence_length != 0:
            max_length = ((max_length // self.sequence_length) + 1) * self.sequence_length

        # Pad or truncate transformed_real and transformed_imag to max_length
        transformed_real = np.pad(transformed_real, (0, max_length - len(transformed_real)), mode='constant') if len(transformed_real) < max_length else transformed_real[:max_length]
        transformed_imag = np.pad(transformed_imag, (0, max_length - len(transformed_imag)), mode='constant') if len(transformed_imag) < max_length else transformed_imag[:max_length]
        #print(f"Rescaled transformed_real after paaaaaaaaaaaading: {transformed_real}")
        #print(f"Rescaled transformed_imag after paaaaaaaaaaaading: {transformed_imag}")
        # Combine real and imaginary parts
        combined = np.concatenate([transformed_real.reshape(-1, 1), transformed_imag.reshape(-1, 1)], axis=-1)
        #print(f"Combined Data before reshape after padding: {combined}")
        if combined.shape[0] != max_length:
            raise ValueError("Unexpected sequence length after padding/truncation.")

        combined = combined.reshape(-1, self.sequence_length, 2)        
        #print(f"Transformed Real Part in process: {transformed_real}")
        #print(f"Transformed Imaginary Part in process: {transformed_imag}")
        #print(f"Combined Data after reshape at the end of process: {combined}")

        return combined

    def __next__(self):
        if self.max_samples and self.total_samples_processed >= self.max_samples:
            raise StopIteration("Reached max_samples limit.")

        while len(self.samples_buffer) < self.batch_size * self.sequence_length:
            try:
                chunk = next(self.dataframe_iterator)
                self.samples_buffer.append(chunk)
                if not self.for_training and self.labels_iterator is not None:
                    label_chunk = next(self.labels_iterator)
                    self.labels_buffer.append(label_chunk)
            except StopIteration:
                if self.current_file_idx >= len(self.file_list):
                    raise StopIteration("No more data to process.")
                self._load_next_file()
        #print(f"Buffer Size Before Slicing: {len(self.samples_buffer)}")
        samples = self.samples_buffer[:self.batch_size * self.sequence_length]
        self.samples_buffer = self.samples_buffer[self.batch_size * self.sequence_length:]
        #print(f"Buffer Size After Slicing: {len(self.samples_buffer)}")
        #print(f"Sample Size Before Processing: {len(samples)}")
        #print('samples in next before send to process:', samples)
        X_chunk = self.process_data(np.array(samples))
        #print(f"X_chunk (Input Data) after process samples: {X_chunk}")
        
        if X_chunk is None:
            raise ValueError("Incorrect chunk size, unable to reshape.")

        num_transformed_samples = X_chunk.shape[0] * X_chunk.shape[1]  # batch_size * new_sequence_length

        if not self.for_training:
            labels = self.labels_buffer[:num_transformed_samples]
            self.labels_buffer = self.labels_buffer[num_transformed_samples:]
            return X_chunk, np.array(labels)
        else:
            return X_chunk, X_chunk
#         if not self.for_training:
#             labels = self.labels_buffer[:self.batch_size * self.sequence_length]
#             self.labels_buffer = self.labels_buffer[self.batch_size * self.sequence_length:]
#             return X_chunk, np.array(labels)
#         else:
#             return X_chunk, X_chunk
        
    def close(self):
        self.samples_buffer = []
        self.labels_buffer = []
        self.total_samples_processed = 0
        self.current_file_idx = 0
        self.dataframe_iterator = None
        self.labels_iterator = None   
# LSTM Autoencoder Model
class SelfAttentionLayer(Layer):
    def __init__(self, num_heads, key_dim):
        super(SelfAttentionLayer, self).__init__()
        self.multi_head_attention = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)

    def call(self, inputs):
        return self.multi_head_attention(inputs, inputs, inputs)

sequence_length = 10
model = Sequential()
model.add(Masking(mask_value=0., input_shape=(sequence_length, 2)))  # Add masking layer
model.add(LSTM(50, activation='relu', return_sequences=True))
#model.add(LSTM(50, activation='relu', input_shape=(sequence_length, 2), return_sequences=True))
model.add(SelfAttentionLayer(num_heads=4, key_dim=50))
model.add(LSTM(25, activation='relu', return_sequences=False))
model.add(RepeatVector(sequence_length))
model.add(LSTM(25, activation='relu', return_sequences=True))
model.add(LSTM(50, activation='relu', return_sequences=True))
model.add(TimeDistributed(Dense(2)))

model.compile(optimizer='adam', loss=custom_loss)

# Model Training
batch_size = 20
max_train_samples = 500000
train_steps = max_train_samples // (batch_size * sequence_length)
max_samples = 1000000  # Maximum samples to read (or None to read all)
max_test_samples = 1000000
#pure_file_pattern = '/home/mreza/5G accelerator/ID_MEC/data generator/pure_data/pure_iq_samples_*.csv'
#mixed_file_pattern = '/home/mreza/5G accelerator/ID_MEC/data generator/mixed_data/mixed_iq_samples_*.csv'
pure_file_pattern = 'C:\\Users\\Mohammadreza\\Desktop\\My Class\\Proj-DC\\My Works\\My Papers\\intrusion\\data generator\\pure_data\\pure_iq_samples_*.csv'
mixed_file_pattern = 'C:\\Users\\Mohammadreza\\Desktop\\My Class\\Proj-DC\\My Works\\My Papers\\intrusion\\data generator\\mixed_data\\mixed_iq_samples_*.csv'
num_epochs = 5
steps_per_epoch = train_steps

train_gen_instance = CSVDataGenerator(pure_file_pattern, batch_size, sequence_length, 
                                      max_train_samples, for_training=True)
combined_gen_instance = CSVDataGenerator(mixed_file_pattern, batch_size, sequence_length, 
                                         max_test_samples, for_training=False)
# combined_gen_instance = CSVDataGenerator(mixed_file_pattern, batch_size, sequence_length, 
#                                          max_train_samples, for_training=False)

# for epoch in range(num_epochs):
#     print(f"Epoch {epoch + 1}/{num_epochs}")
#     train_gen_instance.__iter__() # Reset the generator at the beginning of each epoch
#     for step in range(steps_per_epoch):
#         try:
#             X_chunk, Y_chunk = next(train_gen_instance)
#             #X_chunk_transformed = train_gen_instance.process_data(X_chunk)
#         except StopIteration:
#             train_gen_instance.__iter__()
#             X_chunk, Y_chunk = next(train_gen_instance)
#         #model.train_on_batch(X_chunk, Y_chunk)
#         loss = model.train_on_batch(X_chunk, Y_chunk)
#         if step % 100 == 0:  # Adjust the frequency of logs as needed
#             print(f"Step {step + 1}/{steps_per_epoch}, Loss: {loss}")
#         #print(f"Step {step + 1}/{steps_per_epoch}", end='\r')
#     print()
for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}/{num_epochs}")
    train_gen_instance.__iter__()  # Reset the generator at the beginning of each epoch
    for step in range(steps_per_epoch):
        try:
            X_chunk, Y_chunk = next(train_gen_instance)
        except StopIteration:
            train_gen_instance.__iter__()
            X_chunk, Y_chunk = next(train_gen_instance)

        # Train the model on the batch and get the loss value
        loss = model.train_on_batch(X_chunk, Y_chunk)

        # Print the loss and check for NaN in predictions every 100 steps
        if step % 100 == 0:  # Adjust the frequency of logs as needed
            print(f"Step {step + 1}/{steps_per_epoch}, Loss: {loss}")

            # Check for NaN in model predictions
            pred_sample = model.predict(X_chunk[:1])
            if np.isnan(pred_sample).any():
                print("NaN detected in model predictions during training.")
                break  # Optional: break the loop if NaN is detected

    print()  # Newline for better readability

# Prediction Phase Setup
num_predictions = 100
print(f"Number of predictions to be performed: {num_predictions}")

combined_gen_instance.reset_for_prediction()

predicted_labels = []
true_labels = []
reconstruction_errors = []
all_X_chunk_test = []
all_X_chunk_pred = []

all_intrusion_flags = []
accuracies = []

default_threshold = 0.5  # Define a default threshold
last_valid_threshold = default_threshold  # Initialize the last valid threshold

# Prediction Loop
try:    
    for i in range(num_predictions):
        print(f'Prediction number: {i}')
        X_chunk_test, current_labels = next(combined_gen_instance)
        print('len(X_chunk_test):', len(X_chunk_test))
        print('len(current_labels):', len(current_labels))
        #print('X_chunk_test:', X_chunk_test)
        #print('current_labels:', current_labels)

        # Ensure X_chunk_test shape is correct
        if X_chunk_test.shape[1] != sequence_length or X_chunk_test.shape[2] != 2:
            raise ValueError(f"Incorrect shape for X_chunk_test: {X_chunk_test.shape}")

        X_chunk_pred = model.predict(X_chunk_test)
        #print('X_chunk_pred:', X_chunk_pred)
        print('len(X_chunk_pred):', len(X_chunk_pred))

        # Compute errors
        chunk_errors = np.mean(np.square(X_chunk_test - X_chunk_pred), axis=1)
        max_error_per_sequence = chunk_errors.max(axis=1)

        if max_error_per_sequence.size == 0:
            print("max_error_per_sequence is empty, skipping this batch.")
            continue

        # Determine the actual number of sequences
        num_sequences = X_chunk_test.shape[0]
        error_per_sequence = max_error_per_sequence.reshape(num_sequences, -1).mean(axis=1)
        print('error_per_sequence:', error_per_sequence)

        # Handle NaN values in error_per_sequence for threshold calculation
        if not np.isnan(error_per_sequence).any():
            threshold1 = np.nanpercentile(error_per_sequence, 95)
            last_valid_threshold = threshold1  # Update last valid threshold
        else:
            print("NaN values present in error_per_sequence, using last valid or default threshold")
            threshold1 = last_valid_threshold

        print(f'Threshold1: {threshold1}')
        intrusion_detected_inloop = error_per_sequence > threshold1
        batch_accuracy = accuracy_score(current_labels[:len(error_per_sequence)], intrusion_detected_inloop)
        print('batch_accuracy:', batch_accuracy)
        accuracies.append(batch_accuracy)

        # Append to respective lists
        true_labels.extend(current_labels[:len(error_per_sequence)])
        predicted_labels.extend(intrusion_detected_inloop)
        reconstruction_errors.extend(chunk_errors)
        all_X_chunk_test.append(X_chunk_test)
        all_X_chunk_pred.append(X_chunk_pred)

except StopIteration:
    print("All samples processed.")
    

reconstruction_error = np.array(reconstruction_errors)
print('reconstruction_error.shape:', reconstruction_error.shape)
#print('reconstruction_error:', reconstruction_error)
# max_error_per_sequence = reconstruction_error.reshape(-1, 2).max(axis=1)  # Shape (num_predictions * batch_size * sequence_length,)
# print('max_error_per_sequence.shape:', max_error_per_sequence.shape)
# print('max_error_per_sequence:', max_error_per_sequence)
max_error_per_sequence = reconstruction_error.max(axis=1)
print('max_error_per_sequence.shape:', max_error_per_sequence.shape)
#print('max_error_per_sequence:', max_error_per_sequence)
# error_per_sequence = max_error_per_sequence.reshape(-1, sequence_length).mean(axis=1)  # Shape (num_predictions * batch_size,)
# print('error_per_sequence:', error_per_sequence)
# threshold1 = np.percentile(error_per_sequence, 95)
threshold1 = np.percentile(max_error_per_sequence, 95)
print('threshold1:', threshold1)
threshold2 = np.percentile(reconstruction_error, 95)
print('threshold percentile:', threshold2)

is_intrusion_detected = error_per_sequence > threshold1  # Boolean array for sequences, shape (num_predictions * batch_size,)
num_total_sequences = num_predictions * batch_size - num_predictions
print('len(is_intrusion_detected):', len(is_intrusion_detected))
print('num_total_sequences:', num_total_sequences)
#---------------------------------------finish 111-----------------------------------
flat_error_per_sequence = error_per_sequence.flatten()
# Determine if intrusion detected for each sequence
for error in flat_error_per_sequence:
    all_intrusion_flags.append(error > threshold1)    
all_X_chunk_test = np.concatenate(all_X_chunk_test, axis=0)
all_X_chunk_pred = np.concatenate(all_X_chunk_pred, axis=0)
save_path = 'C:\\Users\\Mohammadreza\\Desktop\\My Class\\Proj-DC\\My Works\\My Papers\\intrusion\\data generator\\intrusion_detected'
#plot_with_intrusions8(all_X_chunk_test, all_X_chunk_pred, all_intrusion_flags, sequence_length, save_path)

jamming_detected = reconstruction_error > threshold1
train_gen_instance.close()
combined_gen_instance.close()
#Table to get insight
flattened_jamming_detected = jamming_detected.flatten()
real_part_detected = jamming_detected[:, 0]
imag_part_detected = jamming_detected[:, 1]

real_true_count = np.sum(real_part_detected)
real_false_count = len(real_part_detected) - real_true_count

imag_true_count = np.sum(imag_part_detected)
imag_false_count = len(imag_part_detected) - imag_true_count
# Overall
overall_true_count = np.sum(flattened_jamming_detected)
overall_false_count = len(flattened_jamming_detected) - overall_true_count
# Table-DataFrame
df = pd.DataFrame({
    'Part': ['Real', 'Imaginary', 'Overall'],
    'True Count': [real_true_count, imag_true_count, overall_true_count],
    'False Count': [real_false_count, imag_false_count, overall_false_count]
})
print(df)
num_jamming_detected = np.sum(jamming_detected)
print(f"Number of jamming sequences detected: {num_jamming_detected} out of {len(flattened_jamming_detected)} sequences")


true_labels = np.array(true_labels).flatten()
predicted_labels = np.array(predicted_labels, dtype=int).flatten()
#predicted_labels = np.array(reconstruction_errors > threshold2, dtype=int).flatten()

# Verify lengths and shapes
print("Length of true labels:", len(true_labels))
print("Length of predicted labels:", len(predicted_labels))

from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, classification_report

try:
    conf_matrix = confusion_matrix(true_labels, predicted_labels)
    roc_auc = roc_auc_score(true_labels, predicted_labels)
    fpr, tpr, _ = roc_curve(true_labels, predicted_labels)
    report = classification_report(true_labels, predicted_labels)

    print("Confusion Matrix:")
    print(conf_matrix)
    print(f"ROC AUC: {roc_auc}")
    print(report)

    # Plot ROC Curve
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()
except Exception as e:
    print("Error in calculating metrics:", e)

#accuracy
plt.plot(accuracies)
plt.title('Accuracy')
plt.xlabel('Batch Number')
plt.ylabel('Accuracy')
plt.show()

plt.figure(figsize=(12, 6))  # Increase the size of the plot
plt.plot(accuracies, linewidth=2)  # Increase line width for better visibility
plt.title('Accuracy Prediction', fontsize=16, fontweight='bold')
plt.xlabel('Batch Number', fontsize=14, fontweight='bold')
plt.ylabel('Accuracy', fontsize=14, fontweight='bold')
# Increase font size and bold x-axis and y-axis values
for label in (plt.gca().get_xticklabels() + plt.gca().get_yticklabels()):
    label.set_fontsize(12)
    label.set_fontweight('bold')
plt.ylim(0, 1)  # Set y-axis limit to range from 0 to 1 (as accuracy ranges between 0 and 1)
plt.grid(True)  # Add grid for better readability
plt.show()


accuracies_series = pd.Series(accuracies)

# Calculate the rolling mean (moving average) with a specified window size
window_size = 10  # By Adjusting this we can change the smoothing level
smoothed_accuracies = accuracies_series.rolling(window=window_size).mean()

# Plotting
plt.figure(figsize=(12, 6))
plt.plot
# Step 2201/2500, Loss: 0.0013292033690959215
# 1/1 [==============================] - 0s 22ms/step
# Step 2301/2500, Loss: 0.0025456168223172426
# 1/1 [==============================] - 0s 23ms/step
# Step 2401/2500, Loss: 0.0014636539854109287
# 1/1 [==============================] - 0s 21ms/step
#
# Number of predictions to be performed: 100
# Processing file: C:\Users\Mohammadreza\Desktop\My Class\Proj-DC\My Works\My Papers\intrusion\data generator\mixed_data\mixed_iq_samples_1.csv
# Prediction number: 0
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 21ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00077114 0.00011659]
# Threshold1: 0.0007384119835306913
# batch_accuracy: 0.5
# Prediction number: 1
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 21ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00087479 0.00035314]
# Threshold1: 0.0008487091380629525
# batch_accuracy: 0.5
# Prediction number: 2
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00102034 0.0001159 ]
# Threshold1: 0.0009751167750767766
# batch_accuracy: 0.5
# Prediction number: 3
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [9.70097252e-04 1.16252553e-05]
# Threshold1: 0.0009221736524116848
# batch_accuracy: 0.5
# Prediction number: 4
# len(X_chunk_test): 36
# len(current_labels): 360
# 2/2 [==============================] - 0s 7ms/step
# len(X_chunk_pred): 36
# error_per_sequence: [5.43021102e-06 3.61757314e-04 3.61757314e-04 8.90230340e-06
#  3.61757314e-04 3.61757314e-04 3.61757314e-04 3.61757314e-04
#  1.05914722e-05 7.19916565e-06 1.16252553e-05 5.64041339e-06
#  7.88835913e-03 6.20265140e-04 1.65204267e-02 7.05007581e-06
#  6.92725532e-06 5.12503810e-06 9.39978984e-06 3.61757314e-04
#  8.60040215e-06 5.15051536e-06 3.61757314e-04 6.57191037e-06
#  3.61757314e-04 3.61757314e-04 3.61757314e-04 3.61757314e-04
#  3.61757314e-04 3.61757314e-04 3.61757314e-04 3.61757314e-04
#  5.12503810e-06 3.61757314e-04 3.61757314e-04 5.54005779e-06]
# Threshold1: 0.002437288637984428
# batch_accuracy: 0.9444444444444444
# Prediction number: 5
# len(X_chunk_test): 18
# len(current_labels): 180
# 1/1 [==============================] - 0s 28ms/step
# len(X_chunk_pred): 18
# error_per_sequence: [8.60815475e-06 1.57691234e-05 5.46998548e-05 2.23247982e-04
#  1.05471732e-02 3.13634819e-04 4.03446889e-04 2.63755004e-04
#  2.48827482e-04 9.56263542e-03 3.78299732e-04 4.12641922e-04
#  1.33678551e-05 3.70691078e-05 3.61757314e-04 1.01680855e-05
#  8.90230340e-06 8.74007818e-06]
# Threshold1: 0.009710316093743334
# batch_accuracy: 0.9444444444444444
# Prediction number: 6
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00130016 0.00058973]
# Threshold1: 0.0012646423773119183
# batch_accuracy: 0.5
# Prediction number: 7
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.0020798  0.00111454]
# Threshold1: 0.002031533998780523
# batch_accuracy: 0.5
# Prediction number: 8
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00173183 0.00071568]
# Threshold1: 0.0016810222762763047
# batch_accuracy: 0.5
# Prediction number: 9
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence:
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00334597 0.00084498]
# Threshold1: 0.0032209188906480494
# batch_accuracy: 0.5
# Prediction number: 18
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00094664 0.00038645]
# Threshold1: 0.0009186256763287285
# batch_accuracy: 0.5
# Prediction number: 19
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00062993 0.00022495]
# Threshold1: 0.0006096836207641112
# batch_accuracy: 0.5
# Prediction number: 20
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.0004547 0.0003313]
# Threshold1: 0.0004485335878253058
# batch_accuracy: 0.5
# Prediction number: 21
# len(X_chunk_test): 26
# len(current_labels): 260
# 1/1 [==============================] - 0s 27ms/step
# len(X_chunk_pred): 26
# error_per_sequence: [1.55734463e-04 3.07406368e-05 1.61206153e-04 4.07831401e-04
#  5.54162220e-04 1.82417446e-02 3.56760825e-04 7.14854722e-04
#  2.60349030e-04 3.13545069e-04 1.94799049e-04 2.10260753e-04
#  2.08462143e-04 1.07512204e-02 1.41254127e-04 2.49882194e-04
#  2.25665095e-04 2.84711369e-05 2.78205053e-05 1.56545686e-05
#  6.71770333e-06 4.26153748e-06 3.68326812e-06 3.61757314e-04
#  3.61757314e-04 7.06502705e-06]
# Threshold1: 0.008242129012139493
# batch_accuracy: 0.07692307692307693
# Prediction number: 22
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [1.65154185e-03 2.42782472e-05]
# Threshold1: 0.0015701786718122107
# batch_accuracy: 0.5
# Prediction number: 23
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [1.59065528e-03 5.28952449e-05]
# Threshold1: 0.0015137672745914007
# batch_accuracy: 0.5
# Prediction number: 24
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00052751 0.00014705]
# Threshold1: 0.0005084875242507648
# batch_accuracy: 0.5
# Prediction number: 25
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00129406 0.00024573]
# Threshold1: 0.0012416397002000211
# batch_accuracy: 0.5
# Prediction number: 26
# len(X_chunk_test): 47
# len(current_labels): 470
# 2/2 [==============================] - 0s 9ms/step
# len(X_chunk_pred): 47
# error_per_sequence: [5.43021102e-06 3.61757314e-04 3.61757314e-04 8.60040215e-06
#  3.61757314e-04 6.26978933e-06 3.61757314e-04 1.81727153e-05
#  3.61757314e-04 8.76467627e-06 7.61028348e-03 3.13048253e-03
#  6.85168839e-06 3.61757314e-04 8.37895226e-06 3.79367130e-05
#  8.71205394e-06 5.02435382e-03 3.48643153e-03 7.19908255e-06
#  1.39955205e-05 1.65474962e-04 3.61757314e-04 7.05007581e-06
#  5.04599117e-06 3.61757314e-04 4.56513128e-06 3.61757314e-04
#  1.39321384e-05 8.32408619e-06 6.70403279e-06 3.61757314e-04
#  4.13118740e-06 3.61757314e-04 3.61757314e-04 2.06571864e-05
#  3.61757314e-04 4.13118740e-06 5.12503407e-06 3.61757314e-04
#  8.37895344e-06 3.61757314e-04 3.61757314e-04 3.61757314e-04
#  4.26484896e-06 3.61757314e-04 5.64040563e-06]
# Threshold1: 0.003379646831833855
# batch_accuracy: 0.9361702127659575
# Prediction number: 27
# len(X_chunk_test): 55
# len(current_labels): 550
# 2/2 [==============================] - 0s 11ms/step
# len(X_chunk_pred): 55
# error_per_sequence: [5.43021102e-06 3.61757314e-04 3.61757314e-04 1.96994256e-05
#  5.54005779e-06 1.39231489e-05 9.39978984e-06 1.10420833e-05
#  1.03855642e-05 1.96114646e-04 8.80683664e-03 1.65750288e-04
#  3.03649405e-05 2.43794510e-04 4.38053468e-05 1.87152431e-04
#  2.05117983e-04 4.92038066e-05 1.76437271e-04 2.04942852e-04
#  5.64041339e-06 3.61757314e-04 7.42015897e-06 2.35205839e-05
#  4.47691529e-05 8.14264411e-03 6.26978933e-06 3.61757314e-04
#  3.61757314e-04 2.77491369e-05 1.42398293e-05 9.07805791e-06
#  2.86886952e-05 3.68326812e-06 2.51778359e-05 6.78887873e-06
#  3.61757314e-04 2.42638658e-05 1.54242661e-05 4.26484798e-06
#  3.61757314e-04 3.61757314e-04 3.61757314e-04 3.61757314e-04
#  6.92725532e-06 3.61757314e-04 3.61757314e-04 6.92725532e-06
#  3.61757314e-04 3.61757314e-04 3.61757314e-04 3.61757314e-04
#  3.61757314e-04 3.61757314e-04 6.92725532e-06]
# Threshold1: 0.00036175731432891363
# batch_accuracy: 0.9636363636363636
# Prediction number: 28
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00318539 0.0003914 ]
# Threshold1: 0.003045692087236997
# batch_accuracy: 0.5
# Prediction number: 29
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 25ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00384955 0.00120901]
# Threshold1: 0.0037175252878824637
# batch_accuracy: 0.5
# Prediction number: 30
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00168844 0.00038609]
# Threshold1: 0.001623324974845839
# batch_accuracy: 0.5
# Prediction number: 31
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.004329   0.00047076]
# Threshold1: 0.004136088636295426
# batch_accuracy: 0.5
# Prediction number: 32
# len(X_chunk_test): 23
# len(current_labels): 230
# 1/1 [==============================] - 0s 26ms/step
# len(X_chunk_pred): 23
# error_per_sequence: [8.45800323e-06 6.92725532e-06 5.23062378e-05 1.60925725e-04
#  3.92124428e-04 1.20484837e-05 3.81385550e-04 3.46599388e-04
#  2.39120053e-04 9.83331789e-03 1.19367459e-02 2.59104502e-04
#  3.41294121e-04 3.22017944e-04 2.75032923e-04 2.39708727e-05
#  1.37291803e-04 1.35907701e-05 5.50546822e-06 3.04520513e-05
#  6.92725532e-06 8.76467627e-06 1.00098248e-05]
# Threshold1: 0.008889198543262256
# batch_accuracy: 0.9130434782608695
# Prediction number: 33
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [6.51286708e-04 2.84788571e-05]
# Threshold1: 0.0006201463151039257
# batch_accuracy: 0.5
# Prediction number: 34
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00240191 0.00077667]
# Threshold1: 0.0023206492004564303
# batch_accuracy: 0.5
# Prediction number: 35
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [1.32595082e-03 3.82352750e-05]
# Threshold1: 0.0012615650394836126
# batch_accuracy: 0.5
# Prediction number: 36
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00141605 0.00026337]
# Threshold1: 0.0013584129679259037
# batch_accuracy: 0.5
# Prediction number: 37
# len(X_chunk_test): 58
# len(current_labels): 580
# 2/2 [==============================] - 0s 10ms/step
# len(X_chunk_pred): 58
# error_per_sequence: [5.43021102e-06 3.61757314e-04 3.61757314e-04 6.92725532e-06
#  1.00098248e-05 3.61757314e-04 3.61757314e-04 3.61757314e-04
#  3.61757314e-04 3.61757314e-04 4.26484798e-06 8.74007818e-06
#  3.61757314e-04 8.90230340e-06 3.61757314e-04 1.10917153e-05
#  1.51083658e-05 6.27358608e-06 1.00098248e-05 3.61757314e-04
#  8.76467627e-06 3.61757314e-04 3.61757314e-04 1.14762070e-05
#  2.89577534e-05 8.75547029e-06 5.12503810e-06 2.35808210e-03
#  5.92337672e-03 1.16869832e-05 8.51301383e-03 1.13855103e-05
#  7.05007581e-06 4.47514422e-05 8.37895226e-06 6.27358608e-06
#  7.19916565e-06 1.60425345e-05 7.90352284e-06 8.90230340e-06
#  3.61757314e-04 3.61757314e-04 6.42843289e-06 5.32792232e-05
#  8.30891975e-06 3.66848989e-06 6.40509767e-06 6.85178233e-06
#  6.70407457e-06 3.61757314e-04 3.61757314e-04 3.61757314e-04
#  8.32408619e-06 3.61757314e-04 5.15051536e-06 3.61757314e-04
#  3.61757314e-04 8.90230340e-06]
# Threshold1: 0.000661206032044501
# batch_accuracy: 0.9482758620689655
# Prediction number: 38
# len(X_chunk_test): 43
# len(current_labels): 430
# 2/2 [==============================] - 0s 8ms/step
# len(X_chunk_pred): 43
# error_per_sequence: [5.43021102e-06 3.61757314e-04 8.32408619e-06 6.92725532e-06
#  3.61757314e-04 3.61757314e-04 5.12503810e-06 8.60040215e-06
#  3.61757314e-04 8.76467627e-06 3.90903060e-05 1.33800603e-04
#  5.15051536e-06 1.49084768e-05 1.22600954e-05 1.23807277e-05
#  1.40660147e-05 1.79649538e-04 4.29088106e-05 2.32946208e-05
#  1.01548851e-02 7.36411694e-03 4.84819584e-05 3.99967914e-05
#  4.54733718e-05 2.16228544e-05 1.65958377e-04 1.72018490e-04
#  4.17285520e-05 6.42832778e-06 5.50546822e-06 1.44385065e-05
#  2.00117047e-04 9.39979102e-06 1.12387597e-05 5.54005004e-06
#  5.12503407e-06 8.58330912e-06 7.15234568e-06 9.39979102e-06
#  8.90230458e-06 2.97354438e-05 8.32409109e-06]
# Threshold1: 0.00036175731432891363
# batch_accuracy: 0.9534883720930233
# Prediction number: 39
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00235707 0.00397172]
# Threshold1: 0.003890987502177805
# batch_accuracy: 0.5
# Prediction number: 40
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00243499 0.00062824]
# Threshold1: 0.0023446481701638235
# batch_accuracy: 0.5
# Prediction number: 41
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [2.43299967e-03 7.62653437e-05]
# Threshold1: 0.002315162957180039
# batch_accuracy: 0.5
# Prediction number: 42
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00110482 0.00033294]
# Threshold1: 0.00106622801737525
# batch_accuracy: 0.5
# Prediction number: 43
# len(X_chunk_test): 10
# len(current_labels): 100
# 1/1 [==============================] - 0s 26ms/step
# len(X_chunk_pred): 10
# error_per_sequence: [1.84584716e-04 2.68003065e-04 2.76552644e-02 3.06052832e-04
#  1.63568492e-02 4.08337908e-04 7.43660738e-04 2.40725646e-04
#  1.51022909e-05 1.79811706e-05]
# Threshold1: 0.02257097753279376
# batch_accuracy: 0.9
# Prediction number: 44
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [1.99004606e-03 4.55083136e-05]
# Threshold1: 0.001892819169025074
# batch_accuracy: 0.5
# Prediction number: 45
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 21ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00125166 0.0001986 ]
# Threshold1: 0.0011990118290368264
# batch_accuracy: 0.5
# Prediction number: 46
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s
ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00114319 0.00032657]
# Threshold1: 0.0011023594340545512
# batch_accuracy: 0.5
# Prediction number: 53
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 21ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00097381 0.00049589]
# Threshold1: 0.0009499129856378901
# batch_accuracy: 0.5
# Prediction number: 54
# len(X_chunk_test): 4
# len(current_labels): 40
# 1/1 [==============================] - 0s 25ms/step
# len(X_chunk_pred): 4
# error_per_sequence: [0.00022946 0.01723363 0.00010563 0.00016856]
# Threshold1: 0.014683006934196486
# batch_accuracy: 0.75
# Prediction number: 55
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00489122 0.00773165]
# Threshold1: 0.007589629751344636
# batch_accuracy: 0.5
# Prediction number: 56
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 25ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00267218 0.00028684]
# Threshold1: 0.002552915176103785
# batch_accuracy: 0.5
# Prediction number: 57
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 25ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00122656 0.00059564]
# Threshold1: 0.0011950167551466775
# batch_accuracy: 0.5
# Prediction number: 58
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00075897 0.00014281]
# Threshold1: 0.0007281658975231116
# batch_accuracy: 0.5
# Prediction number: 59
# len(X_chunk_test): 58
# len(current_labels): 580
# 2/2 [==============================] - 0s 11ms/step
# len(X_chunk_pred): 58
# error_per_sequence: [5.43021102e-06 5.04599117e-06 3.61757314e-04 3.61757314e-04
#  3.61757314e-04 1.17026831e-05 7.54005371e-06 5.49354009e-06
#  4.26484798e-06 5.49354009e-06 7.31075092e-06 5.15051536e-06
#  5.12503810e-06 1.88192485e-03 6.61281409e-03 1.62424157e-05
#  7.68584667e-06 8.60040215e-06 5.54005779e-06 1.27870608e-05
#  1.40636286e-05 1.24629186e-05 8.76467627e-06 2.31293109e-05
#  8.58332281e-06 3.25493704e-05 8.60040215e-06 1.16893711e-05
#  1.06361869e-02 1.08153733e-05 6.42832778e-06 4.13118212e-06
#  3.85943712e-05 6.27358608e-06 8.43393382e-06 8.74007818e-06
#  8.90230340e-06 3.61757314e-04 3.86808026e-05 6.92725532e-06
#  1.04675914e-05 8.33208360e-06 1.11564385e-05 3.61757314e-04
#  3.61757314e-04 3.61757314e-04 3.61757314e-04 3.61757314e-04
#  3.61757314e-04 3.61757314e-04 1.00098248e-05 3.61757314e-04
#  1.00098248e-05 3.61757314e-04 3.61757314e-04 3.61757314e-04
#  3.61757314e-04 8.52639847e-06]
# Threshold1: 0.0005897824439420926
# batch_accuracy: 0.9482758620689655
# Prediction number: 60
# len(X_chunk_test): 58
# len(current_labels): 580
# 2/2 [==============================] - 0s 9ms/step
# len(X_chunk_pred): 58
# error_per_sequence: [5.43021102e-06 3.61757314e-04 5.49354009e-06 3.61757314e-04
#  6.40509767e-06 6.70403279e-06 1.56518377e-05 3.61757314e-04
#  3.61757314e-04 6.92725532e-06 1.66601824e-05 1.65084422e-05
#  3.61757314e-04 5.12503810e-06 1.19589727e-05 1.91997524e-05
#  4.34885828e-06 3.61757314e-04 2.40340432e-05 1.34245873e-04
#  4.87310585e-05 4.08087812e-05 2.93687469e-03 5.65303508e-03
#  3.32826578e-05 2.15784888e-05 1.21518718e-05 1.40639697e-05
#  7.05066732e-06 4.34885828e-06 2.91786174e-05 1.41006562e-05
#  5.52001394e-05 9.86890767e-03 8.95381965e-06 3.95041713e-05
#  5.27510134e-05 1.93249454e-05 1.91952932e-05 1.06619062e-05
#  1.63794377e-05 1.04675914e-05 8.90230340e-06 3.61757314e-04
#  9.39978984e-06 8.60040215e-06 1.06192477e-05 5.50546822e-06
#  3.61757314e-04 3.61757314e-04 3.61757314e-04 3.61757314e-04
#  3.61757314e-04 8.37895226e-06 3.61757314e-04 8.37895226e-06
#  3.61757314e-04 8.37895226e-06]
# Threshold1: 0.0007480249209366333
# batch_accuracy: 0.9482758620689655
# Prediction number: 61
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00364392 0.00052867]
# Threshold1: 0.0034881586173021793
# batch_accuracy: 0.5
# Prediction number: 62
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00076648 0.00076217]
# Threshold1: 0.0007662618836819465
# batch_accuracy: 0.5
# Prediction number: 63
# len(X_chunk_test): 1
# len(current_labels): 10
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 1
# error_per_sequence: [0.00119329]
# Threshold1: 0.0011932891654118393
# batch_accuracy: 0.0
# Prediction number: 64
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [2.09646808e-03 1.59269870e-05]
# Threshold1: 0.001992441029140269
# batch_accuracy: 0.5
# Prediction number: 65
# len(X_chunk_test): 3
# len(current_labels): 30
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 3
# error_per_sequence: [2.46082630e-03 5.85218386e-03 4.26484798e-06]
# Threshold1: 0.005513048106325512
# batch_accuracy: 0.3333333333333333
# Prediction number: 66
# len(X_chunk_test): 1
# len(current_labels): 10
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 1
# error_per_sequence: [0.0013262]
# Threshold1: 0.001326199212538428
# batch_accuracy: 0.0
# Prediction number: 67
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 21ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00063018 0.00349491]
# Threshold1: 0.003351672844081277
# batch_accuracy: 0.5
# Prediction number: 68
# len(X_chunk_test): 1
# len(current_labels): 10
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 1
# error_per_sequence: [0.00076694]
# Threshold1: 0.0007669408644251144
# batch_accuracy: 1.0
# Prediction number: 69
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00201602 0.00343524]
# Threshold1: 0.003364278213526007
# batch_accuracy: 0.5
# Prediction number: 70
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00294948 0.00795189]
# Threshold1: 0.007701765398469514
# batch_accuracy: 0.5
# Prediction number: 71
# len(X_chunk_test): 4
# len(current_labels): 40
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 4
# error_per_sequence: [4.81361152e-04 2.69255845e-03 2.90922647e-04 1.56942458e-05]
# Threshold1: 0.002360878857212511
# batch_accuracy: 0.75
# Prediction number: 72
# len(X_chunk_test): 1
# len(current_labels): 10
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 1
# error_per_sequence: [0.00047471]
# Threshold1: 0.00047471437611424613
# batch_accuracy: 1.0
# Prediction number: 73
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00274743 0.00037525]
# Threshold1: 0.002628824332315668
# batch_accuracy: 0.5
# Prediction number: 74
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00051073 0.00030777]
# Threshold1: 0.000500586230120564
# batch_accuracy: 0.5
# Prediction number: 75
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [9.12025551e-04 3.98150704e-05]
# Threshold1: 0.000868415026712616
# batch_accuracy: 0.5
# Prediction number: 76
# len(X_chunk_test): 3
# len(current_labels): 30
# 1/1 [==============================] - 0s 25ms/step
# len(X_chunk_pred): 3
# error_per_sequence: [4.68529791e-03 1.37059522e-02 1.16252553e-05]
# Threshold1: 0.01280388675716876
# batch_accuracy: 0.6666666666666666
# Prediction number: 77
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00057837 0.00038566]
# Threshold1: 0.0005687370169298363
# batch_accuracy: 0.5
# Prediction number: 78
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00448148 0.00013307]
# Threshold1: 0.004264064308777893
# batch_accuracy: 0.5
# Prediction number: 79
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00120311 0.00036511]
# Threshold1: 0.001161208342276878
# batch_accuracy: 0.5
# Prediction number: 80
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 25ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [3.75047416e-04 4.54221389e-05]
# Threshold1: 0.00035856615186918557
# batch_accuracy: 0.5
# Prediction number: 81
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 26ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [4.44409565e-04 5.88070399e-05]
# Threshold1: 0.00042512943908358774
# batch_accuracy: 0.5
# Prediction number: 82
# len(X_chunk_test): 3
# len(current_labels): 30
# 1/1 [==============================] - 0s 25ms/step
# len(X_chunk_pred): 3
# error_per_sequence: [2.46226736e-03 5.85941829e-04 3.98538916e-06]
# Threshold1: 0.0022746348110749847
# batch_accuracy: 0.6666666666666666
# Prediction number: 83
# len(X_chunk_test): 1
# len(current_labels): 10
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 1
# error_per_sequence: [0.00053607]
# Threshold1: 0.0005360682779832638
# batch_accuracy: 1.0
# Prediction number: 84
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 26ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00070495 0.0002041 ]
# Threshold1: 0.000679903411195044
# batch_accuracy: 0.5
# Prediction number: 85
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [1.19686057e-03 8.78077298e-05]
# Threshold1: 0.0011414079280923132
# batch_accuracy: 0.5
# Prediction number: 86
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [0.00616873 0.00069073]
# Threshold1: 0.0058948291258560884
# batch_accuracy: 0.5
# Prediction number: 87
# len(X_chunk_test): 7
# len(current_labels): 70
# 1/1 [==============================] - 0s 27ms/step
# len(X_chunk_pred): 7
# error_per_sequence: [0.00024878 0.01373077 0.00017767 0.01052495 0.00113582 0.0004194
#  0.00023968]
# Threshold1: 0.012769028084697417
# batch_accuracy: 0.8571428571428571
# Prediction number: 88
# len(X_chunk_test): 1
# len(current_labels): 10
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 1
# error_per_sequence: [0.00059626]
# Threshold1: 0.0005962598146724556
# batch_accuracy: 1.0
# Prediction number: 89
# len(X_chunk_test): 1
# len(current_labels): 10
# 1/1 [==============================] - 0s 25ms/step
# len(X_chunk_pred): 1
# error_per_sequence: [0.00250034]
# Threshold1: 0.0025003386276225247
# batch_accuracy: 1.0
# Prediction number: 90
# len(X_chunk_test): 1
# len(current_labels): 10
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 1
# error_per_sequence: [0.00051637]
# Threshold1: 0.0005163719996973408
# batch_accuracy: 1.0
# Prediction number: 91
# len(X_chunk_test): 1
# len(current_labels): 10
# 1/1 [==============================] - 0s 23ms/step
# len(X_chunk_pred): 1
# error_per_sequence: [0.00094062]
# Threshold1: 0.0009406169746867156
# batch_accuracy: 1.0
# Prediction number: 92
# len(X_chunk_test): 7
# len(current_labels): 70
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 7
# error_per_sequence: [2.53967476e-05 2.18160773e-04 7.17875946e-03 8.45772394e-03
#  3.80551985e-04 2.27957762e-05 5.32114453e-06]
# Threshold1: 0.00807403459489783
# batch_accuracy: 0.8571428571428571
# Prediction number: 93
# len(X_chunk_test): 17
# len(current_labels): 170
# 1/1 [==============================] - 0s 27ms/step
# len(X_chunk_pred): 17
# error_per_sequence: [5.43020479e-06 2.16776300e-05 8.34737466e-06 4.13118740e-06
#  5.64707628e-05 4.45574382e-04 4.95946693e-03 6.28956110e-03
#  3.38162123e-04 6.36674579e-04 1.47517514e-04 1.81494866e-05
#  1.15838557e-05 7.05007086e-06 1.95155445e-05 3.61757314e-04
#  5.50546940e-06]
# Threshold1: 0.005225485764785829
# batch_accuracy: 0.9411764705882353
# Prediction number: 94
# len(X_chunk_test): 1
# len(current_labels): 10
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 1
# error_per_sequence: [0.00159886]
# Threshold1: 0.001598863775884226
# batch_accuracy: 1.0
# Prediction number: 95
# len(X_chunk_test): 1
# len(current_labels): 10
# 1/1 [==============================] - 0s 25ms/step
# len(X_chunk_pred): 1
# error_per_sequence: [0.00254794]
# Threshold1: 0.0025479421648783593
# batch_accuracy: 1.0
# Prediction number: 96
# len(X_chunk_test): 2
# len(current_labels): 20
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 2
# error_per_sequence: [6.70594252e-04 7.33219612e-05]
# Threshold1: 0.0006407306376985927
# batch_accuracy: 0.5
# Prediction number: 97
# len(X_chunk_test): 1
# len(current_labels): 10
# 1/1 [==============================] - 0s 22ms/step
# len(X_chunk_pred): 1
# error_per_sequence: [0.0010843]
# Threshold1: 0.0010842976556717464
# batch_accuracy: 1.0
# Prediction number: 98
# len(X_chunk_test): 5
# len(current_labels): 50
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 5
# error_per_sequence: [1.42155153e-04 2.19403619e-04 8.87418072e-03 3.95935533e-04
#  8.33208360e-06]
# Threshold1: 0.007178531680605253
# batch_accuracy: 0.8
# Prediction number: 99
# len(X_chunk_test): 1
# len(current_labels): 10
# 1/1 [==============================] - 0s 24ms/step
# len(X_chunk_pred): 1
# error_per_sequence: [0.00070259]
# Threshold1: 0.0007025884554390895
# batch_accuracy: 1.0
# reconstruction_error.shape: (853, 2)
# max_error_per_sequence.shape: (853,)
# threshold1: 0.004985421685114006
# threshold percentile: 0.0024806650497613534
# len(is_intrusion_detected): 1
# num_total_sequences: 1900
#         Part  True Count  False Count
# 0       Real          22          831
# 1  Imaginary          29          824
# 2    Overall          51         1655
# Number of jamming sequences detected: 51 out of 1706 sequences
# Length of true labels: 853
# Length of predicted labels: 853
# Confusion Matrix:
# [[692 101]
#  [ 54   6]]
# ROC AUC: 0.4863177805800757
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90       793
#            1       0.06      0.10      0.07        60
#
#     accuracy                           0.82       853
#    macro avg       0.49      0.49      0.49       853
# weighted avg       0.87      0.82      0.84       853

# %%
# reconstruction error
plt.figure(figsize=(14, 6))
plt.plot(reconstruction_error, label='Reconstruction Error')
plt.axhline(y=threshold2, color='r', linestyle='--', label='Threshold')
plt.title('Reconstruction Error with Threshold')
plt.xlabel('Sequence Number')
plt.ylabel('Reconstruction Error')
plt.legend()
# plt.savefig('1-Reconstruction Error with Threshold.png')
# plt.close()
plt.show()

# reconstruction error
reconstruction_error_real = reconstruction_error[:, 0]
reconstruction_error_imag = reconstruction_error[:, 1]

# Plot for Real Part
plt.figure(figsize=(14, 6))
plt.plot(reconstruction_error_real, label='Reconstruction Error - Real Part', color='blue')
plt.axhline(y=threshold2, color='r', linestyle='--', label='Threshold')
plt.title('Reconstruction Error for Real Part with Threshold')
plt.xlabel('Sequence Number')
plt.ylabel('Reconstruction Error')
plt.legend()
# plt.savefig('2-Reconstruction Error for Real Part with Threshold.png')
# plt.close()
plt.show()

# Plot for Imaginary Part
plt.figure(figsize=(14, 6))
plt.plot(reconstruction_error_imag, label='Reconstruction Error - Imaginary Part', color='orange')
plt.axhline(y=threshold2, color='r', linestyle='--', label='Threshold')
plt.title('Reconstruction Error for Imaginary Part with Threshold')
plt.xlabel('Sequence Number')
plt.ylabel('Reconstruction Error')
plt.legend()
# plt.savefig('3-Reconstruction Error for Imaginary Part with Threshold.png')
# plt.close()
plt.show()


#Histogram of Reconstruction Errors:
plt.figure(figsize=(14, 6))
plt.hist(reconstruction_error, bins=50, alpha=0.75)
plt.axvline(x=threshold2, color='r', linestyle='--', label='Threshold')
plt.title('Histogram of Reconstruction Errors')
plt.xlabel('Reconstruction Error')
plt.ylabel('Frequency')
plt.legend()
# plt.savefig('4-Histogram of Reconstruction Errors.png')
# plt.close()
plt.show()


#Time Series Plot of IQ Samples:
sample_index = np.random.choice(len(X_chunk_test))
original_sample = X_chunk_test[sample_index]
reconstructed_sample = X_chunk_pred[sample_index]

plt.figure(figsize=(14, 6))
plt.plot(original_sample[:, 0], 'b-', label='Original Real Part')
plt.plot(reconstructed_sample[:, 0], 'r--', label='Reconstructed Real Part')
plt.plot(original_sample[:, 1], 'g-', label='Original Imaginary Part')
plt.plot(reconstructed_sample[:, 1], 'y--', label='Reconstructed Imaginary Part')
plt.title('Original vs Reconstructed IQ Data')
plt.xlabel('Time Steps')
plt.ylabel('Amplitude')
plt.legend()
# plt.savefig('5-Original vs Reconstructed IQ Data.png')
# plt.close()
plt.show()

#Scatter Plot of Reconstruction Errors vs. Real and Imaginary Parts:
avg_real = np.mean(X_chunk_test, axis=1)[:, 0]
avg_imag = np.mean(X_chunk_test, axis=1)[:, 1]

last_errors = np.mean(reconstruction_errors[-len(X_chunk_test):], axis=1)

print("Shape of avg_real:", avg_real.shape)
print("Shape of avg_imag:", avg_imag.shape)
print("Shape of last_errors:", len(last_errors))


plt.figure(figsize=(14, 6))
plt.scatter(avg_real, last_errors, label='Real Part', alpha=0.5)
plt.axhline(y=threshold2, color='r', linestyle='--', label='Threshold')
plt.title('Reconstruction Error vs. Average Real Part')
plt.xlabel('Average Amplitude')
plt.ylabel('Reconstruction Error')
plt.legend()
# plt.savefig('6-Reconstruction Error vs. Average Real Part.png')
# plt.close()
plt.show()

plt.figure(figsize=(14, 6))
plt.scatter(avg_imag, last_errors, label='Imaginary Part', alpha=0.5)
plt.axhline(y=threshold2, color='r', linestyle='--', label='Threshold')
plt.title('Reconstruction Error vs. Average Imaginary Part')
plt.xlabel('Average Amplitude')
plt.ylabel('Reconstruction Error')
plt.legend()
# plt.savefig('7-Reconstruction Error vs. Average Imaginary Part.png')
# plt.close()
plt.show()

# # Define the number of sequences to plot together
n = 1  # Change this to desired number of sequences
sample_length = sequence_length * n

# Select a random starting sequence for plotting
sequence_index = np.random.choice(len(X_chunk_test) - n + 1)

# Extract and concatenate the original and reconstructed samples
original_sample = np.concatenate(X_chunk_test[sequence_index:sequence_index + n])
reconstructed_sample = np.concatenate(X_chunk_pred[sequence_index:sequence_index + n])

# Plot concatenated sequences
plt.figure(figsize=(14, 6))
plt.plot(original_sample[:, 0], 'b-', label='Original Real Part')
plt.plot(reconstructed_sample[:, 0], 'r--', label='Reconstructed Real Part')
plt.plot(original_sample[:, 1], 'g-', label='Original Imaginary Part')
plt.plot(reconstructed_sample[:, 1], 'y--', label='Reconstructed Imaginary Part')
plt.title(f'Original vs Reconstructed IQ Data for {n} Sequences of Length {sequence_length}')
plt.xlabel('Time Steps')
plt.ylabel('Amplitude')
plt.legend()
# plt.savefig('9-Original vs Reconstructed IQ Data for {n} Sequences of Length {sequence_length}.png')
# plt.close()
plt.show()
# Out:
# Shape of avg_real: (1,)
# Shape of avg_imag: (1,)
# Shape of last_errors: 1

# %%
# Repeat for n = 9
n = 1  # Change this to desired number of sequences
sequence_index = np.random.choice(len(X_chunk_test) - n + 1)
original_sample = np.concatenate(X_chunk_test[sequence_index:sequence_index + n])
reconstructed_sample = np.concatenate(X_chunk_pred[sequence_index:sequence_index + n])

plt.figure(figsize=(14, 6))
plt.plot(original_sample[:, 0], 'b-', label='Original Real Part')
plt.plot(reconstructed_sample[:, 0], 'r--', label='Reconstructed Real Part')
plt.plot(original_sample[:, 1], 'g-', label='Original Imaginary Part')
plt.plot(reconstructed_sample[:, 1], 'y--', label='Reconstructed Imaginary Part')
plt.title(f'Original vs Reconstructed IQ Data for {n} Sequences of Length {sequence_length}')
plt.xlabel('Time Steps')
plt.ylabel('Amplitude')
plt.legend()
# plt.savefig('11-Original vs Reconstructed IQ Data for {n} Sequences of Length {sequence_length}.png')
# plt.close()
plt.show()

# %%
# reconstruction error
reconstruction_error_real = reconstruction_error[:, 0]
reconstruction_error_imag = reconstruction_error[:, 1]

# Plot for Real Part
plt.figure(figsize=(14, 6))
mellow_green = '#89C997' 
plt.plot(reconstruction_error_real, label='Reconstruction Error', color=mellow_green)
plt.axhline(y=threshold2, color='r', linestyle='--', label='Threshold')
plt.title('Intrusion Detected by Reconstruction Error',fontsize=16, fontweight='bold')
plt.xlabel('Sequence Number (×10³)', fontsize=16, fontweight='bold')
#plt.xlabel('Sequence Number(*1000)', fontsize=16, fontweight='bold')
plt.ylabel('Reconstruction Error', fontsize=16, fontweight='bold')
for label in (plt.gca().get_xticklabels() + plt.gca().get_yticklabels()):
    label.set_fontsize(12)
    label.set_fontweight('bold')
plt.legend(fontsize=15)
plt.show()

# %%
#accuracy
plt.plot(accuracies)
plt.title('Accuracy')
plt.xlabel('Batch Number')
plt.ylabel('Accuracy')
plt.show()

plt.figure(figsize=(12, 6))  # Increase the size of the plot
plt.plot(accuracies, linewidth=2)  # Increase line width for better visibility
plt.title('Accuracy Prediction', fontsize=16, fontweight='bold')
plt.xlabel('Batch Number', fontsize=14, fontweight='bold')
plt.ylabel('Accuracy', fontsize=14, fontweight='bold')
# Increase font size and bold x-axis and y-axis values
for label in (plt.gca().get_xticklabels() + plt.gca().get_yticklabels()):
    label.set_fontsize(12)
    label.set_fontweight('bold')
plt.ylim(0, 1)  # Set y-axis limit to range from 0 to 1 (as accuracy ranges between 0 and 1)
plt.grid(True)  # Add grid for better readability
plt.show()

# %%
accuracies_series = pd.Series(accuracies)

# Calculate the rolling mean (moving average) with a specified window size
window_size = 10  # Adjust this to change the smoothing level
smoothed_accuracies = accuracies_series.rolling(window=window_size).mean()

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(accuracies, linewidth=2, alpha=0.5, label='Original')  # Slightly transparent original line
plt.plot(smoothed_accuracies, linewidth=2, color='red', label='Smoothed')  # Smoothed line in red
plt.title('Accuracy Prediction', fontsize=16, fontweight='bold')
plt.xlabel('Batch Number', fontsize=14, fontweight='bold')
plt.ylabel('Accuracy', fontsize=14, fontweight='bold')
for label in (plt.gca().get_xticklabels() + plt.gca().get_yticklabels()):
    label.set_fontsize(12)
    label.set_fontweight('bold')
plt.ylim(0, 1)
plt.grid(True)
plt.legend()  # Add legend to distinguish original and smoothed lines
plt.show()
